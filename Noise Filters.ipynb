# %%
import os

import os
import cv2
import time
import random
import numpy as np
import glob
import random
import shutil
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd

from sklearn.model_selection import train_test_split

import torch
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder
import torchvision.transforms as T
import torch.nn as nn
from torchvision.utils import save_image
import torch.nn.functional as F

# %matplotlib inline

# %%
def denorm(img_tensors):
    return img_tensors * stats[1] + stats[0]

# %%
image_size = 64
batch_size = 1
stats = (0.5), (0.5)

# %%
transform = T.Compose([
#             T.Resize(image_size),
#             T.CenterCrop(image_size),
            T.ToTensor(),
            T.Normalize(*stats)
        ])

# %% [markdown]
# ## Covid

# %% [markdown]
# ### Mean Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/COVID/mean'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets/Complete_Lung_Images/COVID/COVID/COVID*'):
    figure_size = 8
#     new_image = cv2.blur(img,(figure_size, figure_size))
    images = cv2.imread(images)
    new_image = cv2.blur(images,(figure_size,figure_size))
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'COVID-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ### Gaussian Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/COVID/gaussian'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets/Complete_Lung_Images/COVID/COVID/COVID*'):
    figure_size = 8
#     new_image = cv2.blur(img,(figure_size, figure_size))
    images = cv2.imread(images)
    new_image = cv2.GaussianBlur(images,(5,5),0)
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'COVID-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ### Median Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/COVID/median'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets/Complete_Lung_Images/COVID/COVID/COVID*'):
    figure_size = 8
#     new_image = cv2.blur(img,(figure_size, figure_size))
    images = cv2.imread(images)
    new_image = cv2.medianBlur(images,9)
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'COVID-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ## Normal

# %% [markdown]
# ### Mean Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/Normal/mean'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets/Complete_Lung_Images/Normal/Normal/Normal*'):
    figure_size = 8
    images = cv2.imread(images)
    new_image = cv2.blur(images,(figure_size,figure_size))
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'Normal-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ### Gaussian Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/Normal/gaussian'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets/Complete_Lung_Images/Normal/Normal/Normal*'):
    figure_size = 8
    images = cv2.imread(images)
    new_image = cv2.GaussianBlur(images,(5,5),0)
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'Normal-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ### Median Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/Normal/median'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets/Complete_Lung_Images/Normal/Normal/Normal*'):
    figure_size = 8
    images = cv2.imread(images)
    new_image = cv2.medianBlur(images,9)
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'Normal-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ## Viral Pneumonia

# %% [markdown]
# ### Mean Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/Viral_Pneumonia/mean'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets\\Complete_Lung_Images\\Viral_Pneumonia\\Viral_Pneumonia\\Viral Pneumonia*'):
    figure_size = 8
    images = cv2.imread(images)
    new_image = cv2.blur(images,(figure_size, figure_size))
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'Viral Pneumonia-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ### Gaussian Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/Viral_Pneumonia/gaussian'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets/Complete_Lung_Images/Viral_Pneumonia/Viral_Pneumonia/Viral Pneumonia*'):
    figure_size = 8
    images = cv2.imread(images)
    new_image = cv2.GaussianBlur(images, (5,5),0)
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'Normal-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ### Median Filter

# %%
sample_dir = 'Generated_Images\\Noise_Filtered_Images\\Viral_Pneumonia\\median'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets\\Complete_Lung_Images\\Viral_Pneumonia\\Viral_Pneumonia\\Viral Pneumonia*'):
    figure_size = 8
    images = cv2.imread(images)
    new_image = cv2.medianBlur(images,9)
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'Normal-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ## Lung Opacity

# %% [markdown]
# ### Mean Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/Lung_Opacity\\mean'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets\\Complete_Lung_Images\\Lung_Opacity\\Lung_Opacity\\Lung_Opacity*'):
    figure_size = 8
    images = cv2.imread(images)
    new_image = cv2.blur(images,(figure_size, figure_size))
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'Lung_Opacity-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ### Gaussian Filter

# %%
sample_dir = 'Generated_Images/Noise_Filtered_Images/Lung_Opacity/gaussian'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets/Complete_Lung_Images/Lung_Opacity/Lung_Opacity/Lung_Opacity*'):
    figure_size = 8
    img = cv2.imread(images)
    new_image = cv2.GaussianBlur(img, (5,5),0)
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'Lung_Opacity-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1

# %% [markdown]
# ### Median Filter

# %%
sample_dir = 'Generated_Images\\Noise_Filtered_Images\\Lung_Opacity\\mean'
os.makedirs(sample_dir, exist_ok=True)

# %%
s_i = 0
for images in glob.glob('Datasets\\Complete_Lung_Images\\Lung_Opacity\\Lung_Opacity\\Lung_Opacity*'):
    figure_size = 8
    images = cv2.imread(images)
    new_image = cv2.medianBlur(images,9)
    new_image = Image.fromarray(np.uint8(new_image))
    new_image = transform(new_image)
    
    filtered_image_name = 'Lung_Opacity-{0:0=4d}.png'.format(s_i)
    save_image(denorm(new_image), os.path.join(sample_dir, filtered_image_name), nrow=8)
    s_i+=1
